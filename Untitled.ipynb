# %%
print("s")
print(5)
# Out:
# s
# 5

# %%
def foo(number):
    return number ** 2 

print(foo(5))
# Out:
# 25

# %%
def foo(number):
    return number ** 2 

foo(5)
# Out:
# 25

# %%
lists = [1,2,5,7]

print(lists)
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
print("hello world")
# Out:
# hello world

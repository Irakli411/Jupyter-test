# %%
print('hello world')
import pandas as pd
# Out:
# hello world

# %%
# Step 1: Import pandas
import pandas as pd

# Step 2: Create a simple DataFrame
data = {
    "Name": ["Ana", "Gio", "Irakli"],
    "Age": [23, 25, 27],
    "City": ["Tbilisi", "Batumi", "Kutaisi"]
}

df = pd.DataFrame(data)

# Step 3: Display the DataFrame
print("Pandas version:", pd.__version__)
print("\nSample DataFrame:")
print(df)

# Step 4: Do a tiny operation to test functionality
print("\nAverage Age:", df["Age"].mean())
# Out:
# Pandas version: 2.2.2
#
# Sample DataFrame:
#      Name  Age     City
# 0     Ana   23  Tbilisi
# 1     Gio   25   Batumi
# 2  Irakli   27  Kutaisi
#
# Average Age: 25.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 jupyter --config-dir
#
# NameError: name 'jupyter' is not defined

# %% [markdown]
# ## Seminar II: Numpy
# October 14, 2025
# _______________________

# %%
# install requirements if needed

# !pip install numpy matplotlib pandas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1 — Simulate a 1D array of simulated daily temperatures
# * Use normal distribution with `mean = 15` and `sd = 25`
# * Simulate 28 days of daily temperatures
# * Save as temps object
# * Convert the from Celsius to Fahrenheit and save as temps_fahrenheit
# $$fahrenheit = 1.8 * celsius + 32$$

# %%
temps = np.random.normal(loc=15, scale=5, size=28)

temps_fahrenheit = temps * 9/5 + 32

# %%
temps.mean()
# Out:
# 15.793187165466739

# %% [markdown]
# #### Print shape and dtype of temps
#
# temps_fahrenheit.shape()

# %%
temps_fahrenheit.shape
# Out:
# (28,)

# %% [markdown]
# #### Reshape temps so that it consists of 4 rows (weeks) and 7 columns (days of week)

# %%
temps = temps.reshape(4,7)
temps
# Out:
# array([[13.15237384, 18.40874665, 15.9360165 , 11.64348385, 15.32627959,
#         22.02988319, 19.06416415],
#        [ 9.30307234, 16.30235646, 27.25182811, 18.9183824 , 16.59115835,
#         17.95298011, 12.27680763],
#        [13.07513445, 15.0796072 , 14.92215963, 12.25222753,  9.29624868,
#         29.23182846, 11.01392353],
#        [12.88161911, 16.61723716, 19.99962959, 20.97601629, 12.88535244,
#         22.57055238, 12.77160216]])

# %% [markdown]
# ####  Use slicing to display
# * all Wednesday values (assume week starting on Monday)
# * Week #2
# * 1st and 3rd week
#
# * verify that all temperatures are higher than 5 degrees Celsius
# * verify that all temperatures are lower than 30 degrees Celsius

# %%
temps_wednesday = temps[:,2]
temps_wednesday
# Out:
# array([15.9360165 , 27.25182811, 14.92215963, 19.99962959])

# %%
temps_week_2 = temps[1]
temps_week_2
# Out:
# array([ 9.30307234, 16.30235646, 27.25182811, 18.9183824 , 16.59115835,
#        17.95298011, 12.27680763])

# %%
temps_week_1_3 = temps[0::2]
temps_week_1_3
# Out:
# array([[13.15237384, 18.40874665, 15.9360165 , 11.64348385, 15.32627959,
#         22.02988319, 19.06416415],
#        [13.07513445, 15.0796072 , 14.92215963, 12.25222753,  9.29624868,
#         29.23182846, 11.01392353]])

# %%
temps >= 5
# Out:
# True

# %%
temps <= 5
# Out:
# array([[False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False],
#        [False, False, False, False, False, False, False]])

# %% [markdown]
# #### Print mean temperatures
# * Overall in Celsius and Fahrenheit
# * For each day in Celsius
# * For each week in Celsius

# %%
temps.mean()
# Out:
# 16.347523991038017

# %%
temps.mean(axis = 0)
# Out:
# array([12.10304994, 16.60198686, 19.52740845, 15.94752752, 13.52475976,
#        22.94631103, 13.78162437])

# %%
temps.mean(axis = 1)
# Out:
# array([16.50870682, 16.94236934, 14.98158992, 16.95742987])

# %%
temps_fahrenheit = temps_fahrenheit.reshape(28,)

# %%
temps = temps.reshape(28,)

# %% [markdown]
# #### Plot both temperature series into 1 plot

# %%
# Plot both series
plt.figure(figsize=(10, 5))
plt.plot( temps, label="Celsius", marker='o')
plt.plot( temps_fahrenheit, label="Fahrenheit", marker='s')

# Add labels, legend, and title
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Daily Temperatures (Celsius vs Fahrenheit)")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### Exercise 2 - Simulate 2D array of artificial stock returns
# * Simulate 1 year of data (252 observations) and 5 stocks
# * Simulate from normal distribution with the defined means and standard deviations
# * Compute sample mean and standard deviation for each of the assets

# %%
np.random.seed(523)
means = np.array([0, -0.01, 0, 0.005, .012])
sds   = np.array([0.01, 0.01, 0.01, 0.01, 0.01])

rets = np.random.normal(means, sds, size=(252, 5))
rets
# Out:
# array([[ 0.00904925, -0.01224031,  0.00595433,  0.00513984,  0.00646023],
#        [-0.00578244, -0.00795696, -0.01992026,  0.02107503,  0.03055087],
#        [ 0.00857693, -0.01815639, -0.00898555,  0.00922171,  0.01338604],
#        ...,
#        [ 0.01265745, -0.00875772, -0.01153265,  0.01408358,  0.01723703],
#        [ 0.0006743 , -0.0197201 , -0.00579779, -0.00822324,  0.00701914],
#        [ 0.00361623, -0.02069303,  0.00706831,  0.0016559 ,  0.0177597 ]])

# %%
rets.mean( axis = 0)
# Out:
# array([ 1.41320328e-05, -1.07849309e-02, -8.33507237e-04,  4.11181118e-03,
#         1.27341943e-02])

# %%
rets.std( axis = 0)
# Out:
# array([0.00962548, 0.01069631, 0.00954285, 0.00974633, 0.0104624 ])

# %% [markdown]
# #### Compute the correlation for each of the asset pairs

# %%
corr_matrix = np.corrcoef(rets, rowvar=False)
print(corr_matrix)
# Out:
# (5, 5)

# %% [markdown]
# #### Extract
# * returns of the 2nd asset for Wednesdays (assume each week has 5 days and the sample starts Monday)
# * all returns of stocks 1 and 4

# %%
rets[2::5,1]
# Out:
# array([-1.81563890e-02, -1.43840674e-02, -9.25868712e-03,  7.13110573e-03,
#        -1.10871466e-02, -2.29951616e-02, -2.31074960e-02, -9.17462600e-03,
#        -8.71908656e-03,  5.55509725e-04, -1.73154221e-02, -1.20377784e-02,
#        -1.04619394e-02, -2.35049606e-02, -1.28556353e-02, -2.51040411e-02,
#        -1.99353846e-02, -1.44622948e-02,  1.18802195e-03, -1.92485781e-02,
#        -9.51558997e-03,  6.85301746e-03, -4.87380466e-03, -1.87061517e-02,
#         1.17432312e-02, -1.23936373e-02, -7.67783768e-03, -6.99793448e-05,
#        -1.29517717e-02,  1.85466012e-02, -1.12323404e-02, -1.19832922e-02,
#        -1.85334449e-02, -3.09602706e-02, -2.01656580e-02,  5.30201585e-04,
#        -3.82450724e-02, -3.50050305e-03, -1.04023085e-02, -1.05311926e-02,
#        [-1.88424937e-03,  3.15672404e-02],
#        [-3.76554354e-03,  6.66199028e-03],
#        [-1.09338477e-02,  1.03173470e-02],
#        [-2.23901009e-02,  4.33221806e-03],
#        [-5.22829919e-03,  2.20734629e-02],
#        [-6.59458527e-03,  1.72558422e-02],
#        [-4.16892926e-03,  2.22989735e-02],
#        [ 1.64655944e-04,  1.20838374e-02],
#        [-1.58682394e-02,  1.43182190e-02],
#        [-1.47653002e-02,  4.46264141e-03],
#        [ 8.60404739e-03,  3.73513230e-02],
#        [-2.87081272e-02,  1.71747519e-02],
#        [-1.33992155e-02,  2.37921395e-02],
#        [-1.82449972e-03,  6.96645375e-03],
#        [-1.81367305e-02,  1.01984545e-02],
#        [ 1.48597605e-03,  1.57722191e-02],
#        [-2.20640340e-02,  1.41801732e-02],
#        [-8.75772065e-03,  1.72370345e-02],
#        [-1.97201043e-02,  7.01913907e-03],
#        [-2.06930286e-02,  1.77596993e-02]])

# %% [markdown]
# #### Identify days where average return across assets is greater than 0

# %%
days_mean = rets.mean(axis = 1).shape
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]

for day in days

# %% [markdown]
# #### Plot the returns
# * Plot the time series of raw returns
# * Assume that you make an initial investment of 1 USD. Compute and plot the evolution of such investment for each asset.

# %% [markdown]
# #### Plot histogram of returns for asset 2

# %% [markdown]
# ---
# ### Exercise 3 — 3D array (image)
#
# First we will load the image into a 3D array

# %% [markdown]
# * Verify that all values are lower or equal than 1
# * Find the range of realized values

# %%
# Verify that all the values are lower than 1

# %% [markdown]
# #### Remove each of the primary colors
# * Create a copy of img and save it as img2
# * Set all the values for `Red` to 0 and display the image
# * Set all the values for `Green` to 0 and display the image
# * Set all the values for `Blue` to 0 and display the image

# %%
# remove red

# %%
# remove green

# %%
# remove blue

# %% [markdown]
# #### Invert the grayscale of the image
# * What was white should be black, etc.

# %%
inverted = img.copy()

# %% [markdown]
# #### Add Gaussian noise to the picture
# * Create an np.array from normal distribution with `mean = 0` and `sd = 0.1` of shape (1024, 1280, 3), and add it to the RGB colors
# * employ clipping of the values to the interval `[0, 1]`

# %%
noisy = img.copy()

# %% [markdown]
# #### Flip the image horizontally
#
# * You can use np.flip()
# * Keep the `A` values

# %% [markdown]
# #### Flatten the image and then reconstruct it

# %% [markdown]
# #### Bonus: create a checkerboard mask to selectively white every other 8×8 block.

# %%
h, w, _ = img.shape
block = 8 

# Compute how many 8×8 blocks fit in each dimension
h_blocks = h // block
w_blocks = w // block

# Create a checkerboard pattern using addition mod 2
checker = (np.add.outer(np.arange(h_blocks), np.arange(w_blocks)) % 2).astype(bool)
mask = np.kron(checker, np.ones((block, block), dtype=bool))

# Apply mask: zero every other block
checker_img = img.copy()
checker_img[~mask] = 1  # zero RGBA pixels in the masked-out blocks

plt.imshow(checker_img)
plt.title("Checkerboard Mask (8×8 Blocks)")
plt.axis("off")
plt.show()
